# %%
# NIM/Nama  : 19622217/Lydia Gracia
# Tanggal   :
# Deskripsi : Program memeriksa ...; input: ...; output: ...

# KAMUS
'''jenis data variabel'''
'''contoh: int, str, bool'''

# %% [markdown]
# 0

# %%
import pandas as pd

df=pd.read_csv("P05-01.csv")

print(df)
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %% [markdown]
# 1. Banyaknya data.

# %%
import pandas as pd

df=pd.read_csv("P05-01.csv")

len(df)
# Out:
# 10127

# %% [markdown]
# 2. Total transaksi tertinggi selama 12 bulan terakhir

# %%
import pandas as pd

df=pd.read_csv("P05-01.csv")

df["Total_Trans_Amt"].max()
# Out:
# 18484

# %% [markdown]
# 3. 5 pengguna dengan total nominal yang belum dibayar terbesar.

# %%
import pandas as pd

df=pd.read_csv("P05-01.csv")

df.sort_values(["Total_Revolving_Bal"], ascending=[False])[:5]
# Out:
#       CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 5003  771795933  Attrited Customer            49      M                4
# 507   712049208  Existing Customer            56      M                3
# 8573  812218908  Attrited Customer            46      F                2
# 2405  715499808  Existing Customer            63      F                0
# 8582  719269308  Existing Customer            49      F                2
#
#      Education_Level Marital_Status Income_Category Card_Category  \
# 5003         Unknown         Single         $120K +          Blue
# 507    Post-Graduate        Married     $60K - $80K          Blue
# 8573         Unknown        Married  Less than $40K          Blue
# 2405         Unknown        Married  Less than $40K          Blue
# 8582        Graduate        Unknown  Less than $40K          Blue
#
#       Months_on_book  Months_Inactive_12_mon  Credit_Limit  \
# 5003              38                       3       34516.0
# ...

# %% [markdown]
# 4. Pengguna dengan tipe kartu kredit Platinum

# %%
import pandas as pd

df=pd.read_csv("P05-01.csv")

df.loc[df["Card_Category"]=="Platinum"]
# Out:
#       CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 443   788386908  Existing Customer            48      M                3
# 650   779519058  Existing Customer            51      F                3
# 3800  708654933  Attrited Customer            51      F                2
# 8631  714754533  Existing Customer            51      M                0
# 8863  714077583  Attrited Customer            43      M                3
# 8897  709269708  Existing Customer            45      M                4
# 9068  719071158  Attrited Customer            54      F                0
# 9071  711364233  Existing Customer            41      M                4
# 9078  823848183  Existing Customer            39      F                1
# 9102  714190983  Attrited Customer            51      F                2
# 9113  770848308  Existing Customer            45      M                2
# 9127  713870958  Existing Customer            56      F                3
# ...

# %% [markdown]
# 5. Nilai korelasi antara jumlah tanggungan dengan nominal limit kartu kredit. Apakah berkorelasi lurus,
# terbalik, atau tidak berkolerasi? Jelaskan.

# %%
import pandas as pd

df=pd.read_csv("P05-01.csv")

df["Dependent_count"].corr(df["Credit_Limit"])
# Out:
# 0.0680646002034699

# %% [markdown]
# jumlah tanggungan dengan nominal limit kartu kredit memiliki korelasi mendekati 0, artinya keduanya tidak berkorelasi
