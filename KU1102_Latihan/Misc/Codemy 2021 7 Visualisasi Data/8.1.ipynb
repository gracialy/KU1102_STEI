# %%
# NIM/Nama  : 19622217/Lydia Gracia
# Tanggal   :
# Deskripsi : Program memeriksa ...; input: ...; output: ...

# KAMUS
'''jenis data variabel'''
'''contoh: int, str, bool'''
# Out:
# 'contoh: int, str, bool'

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("problem-7-1.csv")

print(df)
# Out:
#                                 nama   kendaraan  tingkat
# 0             Mohammad Arfian Farizi       mobil     2016
# 1                  Tria Kasnalestari       mobil     2018
# 2     Hafizhun Lihududillah Soekiswo  jalan kaki     2016
# 3         Janesya Sicilianty Suhelmi      angkot     2017
# 4                Rezky Heidi Saputro      angkot     2018
# ...                              ...         ...      ...
# 9937                     Orvin Demsy  jalan kaki     2016
# 9938               Nicky Ria Azizman       mobil     2017
# 9939              Eva Karisma Lindia      angkot     2016
# 9940    R Sugiri Rachmansyah Nugraha      angkot     2018
# 9941             Angga Pratama Putra      angkot     2017
#
# [9942 rows x 3 columns]

# %% [markdown]
# 1

# %%
len(df)
# Out:
# 9942

# %% [markdown]
# 2

# %%
df["kendaraan"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot: ylabel='kendaraan'>

# %% [markdown]
# 3

# %%
df.loc[df["kendaraan"]=="jalan kaki"]["tingkat"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot: ylabel='tingkat'>

# %% [markdown]
# 4

# %%
print(df["tingkat"].value_counts())

df["tingkat"].plot(kind="hist")
# Out:
# 2016    2690
# 2018    2495
# 2017    2436
# 2015    2321
# Name: tingkat, dtype: int64
# <AxesSubplot: ylabel='Frequency'>

# %% [markdown]
# 5

# %% [markdown]
# 2016

# %% [markdown]
# 6

# %%
df.groupby(["tingkat", "kendaraan"])["nama"].size().unstack().plot(kind="bar", stacked=True)
# Out:
# <AxesSubplot: xlabel='tingkat'>

# %% [markdown]
# 7

# %%
df["Year Last Updated"].value_counts()
# Out:
# 2018    4042
# 2017     872
# 2016     358
# 2015     234
# 2014      99
# 2013      50
# 2012      13
# 2011       8
# 2010       1
# Name: Year Last Updated, dtype: int64

# %% [markdown]
# 8

# %%
y18=df.loc[df["Year Last Updated"]==2016]

y18["Reviews"].mean()
# Out:
# 48653.555865921786

# %% [markdown]
# 9

# %%
free=df.loc[df["Type"]=="Free"]

free["Rating"].mean()
# Out:
# 4.19402390438247

# %% [markdown]
# 10

# %%
df["Reviews"].std()
# Out:
# 2343945.4962195414

# %% [markdown]
# 11

# %%
print(df["Rating"].corr(df["Reviews"])) # tidak berkorelasi
print(df["Rating"].corr(df["Installs"])) # tidak berkorelasi
# Out:
# 0.05672501997160172
# 0.03761333617623016
